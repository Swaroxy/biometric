# %% [markdown]
# This notebook trains a MLPClassifier on the data (numpy arrays) created by the notebook - *process_yale_images.ipynb*.

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

# %%
# Set paths for the local .npy files
data_path = "D:/biometric/yaleExtB_data.npy"
target_path = "D:/biometric/yaleExtB_target.npy"

# %%
# Load the data and target arrays
print("Loading data...")
data = np.load(data_path)
target = np.load(target_path)
# Out:
# Loading data...

# %%
# Verify data shapes
print(f"Data shape: {data.shape}")
print(f"Target shape: {target.shape}")
print(f"Number of unique classes: {len(np.unique(target))}")
# Out:
# Data shape: (1500, 5236)
# Target shape: (1500,)
# Number of unique classes: 30

# %%
# Split into features (X) and labels (y)
X, y = data, target

# %%
# Split into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# PCA to reduce dimensionality
nof_prin_components = 150  # Parameter for number of principal components
print("Performing PCA...")
pca = PCA(n_components=nof_prin_components, whiten=True).fit(X_train)
# Out:
# Performing PCA...

# %%
# Apply PCA transformation
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
# Train a neural network classifier
nohn = 300  # Number of hidden neurons
print("Training the classifier...")
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='adam', activation='relu', 
                     batch_size=256, verbose=True, early_stopping=True, random_state=42)
clf.fit(X_train_pca, y_train)
# Out:
# Training the classifier...
# Iteration 1, loss = 3.51035437
# Validation score: 0.123810
# Iteration 2, loss = 2.95739466
# Validation score: 0.323810
# Iteration 3, loss = 2.48286100
# Validation score: 0.523810
# Iteration 4, loss = 2.05535251
# Validation score: 0.571429
# Iteration 5, loss = 1.67331018
# Validation score: 0.666667
# Iteration 6, loss = 1.33641764
# Validation score: 0.742857
# Iteration 7, loss = 1.05614480
# Validation score: 0.800000
# Iteration 8, loss = 0.82619808
# Validation score: 0.828571
# Iteration 9, loss = 0.64771678
# Validation score: 0.847619
# Iteration 10, loss = 0.50969909
# Validation score: 0.857143
# Iteration 11, loss = 0.40704763
# Validation score: 0.895238
# Iteration 12, loss = 0.32918634
# Validation score: 0.895238
# Iteration 13, loss = 0.27039368
# Validation score: 0.895238
# Iteration 14, loss = 0.22611886
# Validation score: 0.895238
# Iteration 15, loss = 0.19124907
# Validation score: 0.895238
# Iteration 16, loss = 0.16434875
# Validation score: 0.895238
# Iteration 17, loss = 0.14296162
# Validation score: 0.904762
# Iteration 18, loss = 0.12575220
# Validation score: 0.904762
# Iteration 19, loss = 0.11175654
# Validation score: 0.895238
# Iteration 20, loss = 0.09995424
# Validation score: 0.895238
# Iteration 21, loss = 0.09026528
# Validation score: 0.904762
# Iteration 22, loss = 0.08171721
# Validation score: 0.904762
# Iteration 23, loss = 0.07485179
# Validation score: 0.904762
# Iteration 24, loss = 0.06876556
# Validation score: 0.904762
# Iteration 25, loss = 0.06340247
# Validation score: 0.904762
# Iteration 26, loss = 0.05862941
# Validation score: 0.904762
# Iteration 27, loss = 0.05472706
# Validation score: 0.904762
# Iteration 28, loss = 0.05102859
# Validation score: 0.904762
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(batch_size=256, early_stopping=True, hidden_layer_sizes=(300,),
#               random_state=42, verbose=True)

# %% [markdown]
# [Documentation of ML sklearn library](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)

# %%
# Evaluate on the test set
print("Evaluating the classifier...")
y_pred = clf.predict(X_test_pca)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Evaluating the classifier...
# Classification Report:
#               precision    recall  f1-score   support
#
#          2.0       1.00      1.00      1.00        10
#          3.0       0.94      1.00      0.97        15
#          4.0       0.87      1.00      0.93        13
#          5.0       0.86      1.00      0.92        12
#          6.0       1.00      0.94      0.97        16
#          7.0       0.89      0.94      0.91        17
#          8.0       0.93      0.93      0.93        15
#          9.0       0.89      0.89      0.89        19
#         11.0       0.88      0.88      0.88        17
#         12.0       1.00      0.93      0.96        14
#         13.0       1.00      0.91      0.95        11
#         15.0       1.00      1.00      1.00        14
#         16.0       1.00      0.87      0.93        15
#         17.0       1.00      0.79      0.88        14
#         18.0       1.00      1.00      1.00        16
#         20.0       0.92      1.00      0.96        11
#         22.0       1.00      1.00      1.00        12
#         23.0       1.00      1.00      1.00        11
#         24.0       1.00      1.00      1.00        17
#         25.0       1.00      0.90      0.95        20
#         26.0       1.00      1.00      1.00        14
#         27.0       1.00      0.79      0.88        19
#         28.0       0.94      1.00      0.97        15
#         32.0       1.00      1.00      1.00        24
#         33.0       0.84      0.84      0.84        19
#         34.0       1.00      0.92      0.96        13
#         35.0       0.78      0.93      0.85        15
#         37.0       0.85      1.00      0.92        11
#         38.0       0.88      0.94      0.91        16
#         39.0       0.94      1.00      0.97        15
#
#     accuracy                           0.94       450
#    macro avg       0.95      0.95      0.94       450
# weighted avg       0.95      0.94      0.94       450

# %% [markdown]
# The validation accuracy seen in the above output is computed by testing on the training set, so they are not actual validation accuracy.

# %%
# Cross-validation
print("Performing cross-validation...")
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(clf, X_train_pca, y_train, cv=kf, scoring='accuracy')
print(f"Cross-validation scores: {scores}")
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# Performing cross-validation...
# Iteration 1, loss = 3.53710040
# Validation score: 0.107143
# Iteration 2, loss = 3.09272480
# Validation score: 0.202381
# Iteration 3, loss = 2.70408700
# Validation score: 0.333333
# Iteration 4, loss = 2.34449653
# Validation score: 0.464286
# Iteration 5, loss = 2.01141906
# Validation score: 0.583333
# Iteration 6, loss = 1.70714608
# Validation score: 0.761905
# Iteration 7, loss = 1.43367091
# Validation score: 0.785714
# Iteration 8, loss = 1.19241705
# Validation score: 0.821429
# Iteration 9, loss = 0.98425986
# Validation score: 0.845238
# Iteration 10, loss = 0.81151959
# Validation score: 0.869048
# Iteration 11, loss = 0.66859591
# Validation score: 0.869048
# Iteration 12, loss = 0.55219372
# Validation score: 0.880952
# Iteration 13, loss = 0.45841666
# Validation score: 0.880952
# Iteration 14, loss = 0.38489226
# Validation score: 0.892857
# Iteration 15, loss = 0.32496028
# Validation score: 0.892857
# Iteration 16, loss = 0.27735501
# Validation score: 0.904762
# Iteration 17, loss = 0.23842119
# Validation score: 0.904762
# Iteration 18, loss = 0.20796979
# Validation score: 0.904762
# Iteration 19, loss = 0.18167294
# Validation score: 0.904762
# Iteration 20, loss = 0.16062721
# Validation score: 0.916667
# Iteration 21, loss = 0.14238421
# Validation score: 0.916667
# Iteration 22, loss = 0.12798129
# Validation score: 0.916667
# Iteration 23, loss = 0.11511954
# Validation score: 0.916667
# Iteration 24, loss = 0.10443709
# Validation score: 0.916667
# Iteration 25, loss = 0.09571968
# Validation score: 0.916667
# Iteration 26, loss = 0.08757831
# Validation score: 0.916667
# Iteration 27, loss = 0.08054154
# Validation score: 0.916667
# Iteration 28, loss = 0.07454909
# Validation score: 0.916667
# Iteration 29, loss = 0.06942589
# Validation score: 0.916667
# Iteration 30, loss = 0.06451570
# Validation score: 0.916667
# Iteration 31, loss = 0.06038374
# Validation score: 0.916667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 3.56683471
# Validation score: 0.107143
# Iteration 2, loss = 3.12320125
# Validation score: 0.261905
# Iteration 3, loss = 2.73099592
# Validation score: 0.357143
# Iteration 4, loss = 2.36584543
# Validation score: 0.488095
# Iteration 5, loss = 2.02717505
# Validation score: 0.583333
# Iteration 6, loss = 1.71772377
# Validation score: 0.690476
# Iteration 7, loss = 1.43742691
# Validation score: 0.738095
# Iteration 8, loss = 1.19087076
# Validation score: 0.833333
# Iteration 9, loss = 0.98216725
# Validation score: 0.904762
# Iteration 10, loss = 0.80451365
# Validation score: 0.916667
# Iteration 11, loss = 0.65950922
# Validation score: 0.928571
# Iteration 12, loss = 0.54292132
# Validation score: 0.928571
# Iteration 13, loss = 0.44889692
# Validation score: 0.928571
# Iteration 14, loss = 0.37536052
# Validation score: 0.916667
# Iteration 15, loss = 0.31493312
# Validation score: 0.928571
# Iteration 16, loss = 0.26789787
# Validation score: 0.928571
# Iteration 17, loss = 0.22898623
# Validation score: 0.940476
# Iteration 18, loss = 0.19884121
# Validation score: 0.940476
# Iteration 19, loss = 0.17357911
# Validation score: 0.952381
# Iteration 20, loss = 0.15307081
# Validation score: 0.952381
# Iteration 21, loss = 0.13577005
# Validation score: 0.952381
# Iteration 22, loss = 0.12224122
# Validation score: 0.952381
# Iteration 23, loss = 0.10997331
# Validation score: 0.940476
# Iteration 24, loss = 0.10012884
# Validation score: 0.940476
# Iteration 25, loss = 0.09135939
# Validation score: 0.940476
# Iteration 26, loss = 0.08402343
# Validation score: 0.940476
# Iteration 27, loss = 0.07770594
# Validation score: 0.940476
# Iteration 28, loss = 0.07204712
# Validation score: 0.940476
# Iteration 29, loss = 0.06715819
# Validation score: 0.940476
# Iteration 30, loss = 0.06276116
# Validation score: 0.952381
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 3.54126407
# Validation score: 0.095238
# Iteration 2, loss = 3.09813659
# Validation score: 0.190476
# Iteration 3, loss = 2.70188408
# Validation score: 0.297619
# Iteration 4, loss = 2.34124178
# Validation score: 0.476190
# Iteration 5, loss = 2.00579530
# Validation score: 0.571429
# Iteration 6, loss = 1.69766663
# Validation score: 0.666667
# Iteration 7, loss = 1.42398659
# Validation score: 0.702381
# Iteration 8, loss = 1.18011017
# Validation score: 0.785714
# Iteration 9, loss = 0.97380013
# Validation score: 0.821429
# Iteration 10, loss = 0.80020236
# Validation score: 0.869048
# Iteration 11, loss = 0.65553328
# Validation score: 0.869048
# Iteration 12, loss = 0.53773524
# Validation score: 0.869048
# Iteration 13, loss = 0.44447537
# Validation score: 0.880952
# Iteration 14, loss = 0.36984001
# Validation score: 0.892857
# Iteration 15, loss = 0.31057410
# Validation score: 0.904762
# Iteration 16, loss = 0.26259827
# Validation score: 0.904762
# Iteration 17, loss = 0.22384866
# Validation score: 0.904762
# Iteration 18, loss = 0.19350840
# Validation score: 0.904762
# Iteration 19, loss = 0.16869291
# Validation score: 0.904762
# Iteration 20, loss = 0.14869768
# Validation score: 0.916667
# Iteration 21, loss = 0.13200201
# Validation score: 0.916667
# Iteration 22, loss = 0.11800628
# Validation score: 0.928571
# Iteration 23, loss = 0.10656863
# Validation score: 0.928571
# Iteration 24, loss = 0.09678029
# Validation score: 0.928571
# Iteration 25, loss = 0.08878422
# Validation score: 0.928571
# Iteration 26, loss = 0.08146603
# Validation score: 0.928571
# Iteration 27, loss = 0.07519348
# Validation score: 0.928571
# Iteration 28, loss = 0.06980975
# Validation score: 0.928571
# Iteration 29, loss = 0.06496361
# Validation score: 0.928571
# Iteration 30, loss = 0.06076637
# Validation score: 0.928571
# Iteration 31, loss = 0.05701232
# Validation score: 0.940476
# Iteration 32, loss = 0.05347378
# Validation score: 0.940476
# Iteration 33, loss = 0.05037496
# Validation score: 0.940476
# Iteration 34, loss = 0.04744464
# Validation score: 0.940476
# Iteration 35, loss = 0.04499102
# Validation score: 0.940476
# Iteration 36, loss = 0.04264951
# Validation score: 0.940476
# Iteration 37, loss = 0.04043900
# Validation score: 0.940476
# Iteration 38, loss = 0.03835577
# Validation score: 0.940476
# Iteration 39, loss = 0.03649703
# Validation score: 0.940476
# Iteration 40, loss = 0.03483615
# Validation score: 0.940476
# Iteration 41, loss = 0.03315021
# Validation score: 0.940476
# Iteration 42, loss = 0.03177256
# Validation score: 0.940476
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 3.55500163
# Validation score: 0.095238
# Iteration 2, loss = 3.11009718
# Validation score: 0.142857
# Iteration 3, loss = 2.71769602
# Validation score: 0.345238
# Iteration 4, loss = 2.35567084
# Validation score: 0.476190
# Iteration 5, loss = 2.02282281
# Validation score: 0.619048
# Iteration 6, loss = 1.71600703
# Validation score: 0.785714
# Iteration 7, loss = 1.44171516
# Validation score: 0.809524
# Iteration 8, loss = 1.20036655
# Validation score: 0.845238
# Iteration 9, loss = 0.99277004
# Validation score: 0.857143
# Iteration 10, loss = 0.81774267
# Validation score: 0.857143
# Iteration 11, loss = 0.67077681
# Validation score: 0.869048
# Iteration 12, loss = 0.55217133
# Validation score: 0.904762
# Iteration 13, loss = 0.45539233
# Validation score: 0.904762
# Iteration 14, loss = 0.38009858
# Validation score: 0.916667
# Iteration 15, loss = 0.31919794
# Validation score: 0.916667
# Iteration 16, loss = 0.27043459
# Validation score: 0.916667
# Iteration 17, loss = 0.23141321
# Validation score: 0.940476
# Iteration 18, loss = 0.19999402
# Validation score: 0.952381
# Iteration 19, loss = 0.17504947
# Validation score: 0.952381
# Iteration 20, loss = 0.15429878
# Validation score: 0.952381
# Iteration 21, loss = 0.13738273
# Validation score: 0.952381
# Iteration 22, loss = 0.12297508
# Validation score: 0.952381
# Iteration 23, loss = 0.11108674
# Validation score: 0.952381
# Iteration 24, loss = 0.10128021
# Validation score: 0.952381
# Iteration 25, loss = 0.09273816
# Validation score: 0.952381
# Iteration 26, loss = 0.08544569
# Validation score: 0.952381
# Iteration 27, loss = 0.07898518
# Validation score: 0.952381
# Iteration 28, loss = 0.07340862
# Validation score: 0.952381
# Iteration 29, loss = 0.06818906
# Validation score: 0.952381
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 3.57105234
# Validation score: 0.059524
# Iteration 2, loss = 3.11287064
# Validation score: 0.202381
# Iteration 3, loss = 2.70879929
# Validation score: 0.333333
# Iteration 4, loss = 2.33755801
# Validation score: 0.464286
# Iteration 5, loss = 1.99461044
# Validation score: 0.523810
# Iteration 6, loss = 1.68489365
# Validation score: 0.619048
# Iteration 7, loss = 1.40602100
# Validation score: 0.630952
# Iteration 8, loss = 1.16271253
# Validation score: 0.702381
# Iteration 9, loss = 0.95449889
# Validation score: 0.714286
# Iteration 10, loss = 0.78079552
# Validation score: 0.750000
# Iteration 11, loss = 0.63816647
# Validation score: 0.821429
# Iteration 12, loss = 0.52237891
# Validation score: 0.833333
# Iteration 13, loss = 0.42902317
# Validation score: 0.845238
# Iteration 14, loss = 0.35539448
# Validation score: 0.892857
# Iteration 15, loss = 0.29671345
# Validation score: 0.892857
# Iteration 16, loss = 0.24990461
# Validation score: 0.928571
# Iteration 17, loss = 0.21398053
# Validation score: 0.928571
# Iteration 18, loss = 0.18319089
# Validation score: 0.928571
# Iteration 19, loss = 0.15985228
# Validation score: 0.928571
# Iteration 20, loss = 0.14002812
# Validation score: 0.928571
# Iteration 21, loss = 0.12402989
# Validation score: 0.928571
# Iteration 22, loss = 0.11081207
# Validation score: 0.928571
# Iteration 23, loss = 0.09955135
# Validation score: 0.928571
# Iteration 24, loss = 0.08983803
# Validation score: 0.928571
# Iteration 25, loss = 0.08197379
# Validation score: 0.928571
# Iteration 26, loss = 0.07485678
# Validation score: 0.928571
# Iteration 27, loss = 0.06894960
# Validation score: 0.928571
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Cross-validation scores: [0.92380952 0.93809524 0.92857143 0.92857143 0.85714286]
# Mean cross-validation accuracy: 0.9152380952380952

# %%
print(scores)
# Out:
# [0.92380952 0.93809524 0.92857143 0.92857143 0.85714286]
